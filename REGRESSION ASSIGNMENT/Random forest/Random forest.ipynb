# %%
import pandas as pd    #PANDA AS PD LIBRARI FOR OPERATING WITH TABLES
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")  #creating a variable called dataset ,which uses read_csv funtion from lib pd and saving the dataset in the file"50_Startups.csv"
dataset   #printing the dataset to check
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset)  #storing the coloumn yearsofexpirience from the dataset to the variable independent

dataset
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400        True     False      False
# 1      18  33.770         1   1725.55230       False      True       True
# 2      28  33.000         3   4449.46200       False      True       True
# 3      33  22.705         0  21984.47061       False      True       True
# 4      32  28.880         0   3866.85520       False      True       True
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830       False      True       True
# 1334   18  31.920         0   2205.98080        True     False       True
# 1335   18  36.850         0   1629.83350        True     False       True
# 1336   21  25.800         0   2007.94500        True     False       True
# 1337   61  29.070         0  29141.36030        True     False      False
#
#       smoker_yes
# 0           True
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 1333       False
# 1334       False
# 1335       False
# 1336       False
# 1337        True
#
# [1338 rows x 8 columns]

# %%
independent=dataset[['age','bmi','children','sex_female','sex_male','smoker_no','smoker_yes']]  ##storing the colounm salary from the dataset to the variable independent
independent
# Out:
#       age     bmi  children  sex_female  sex_male  smoker_no  smoker_yes
# 0      19  27.900         0        True     False      False        True
# 1      18  33.770         1       False      True       True       False
# 2      28  33.000         3       False      True       True       False
# 3      33  22.705         0       False      True       True       False
# 4      32  28.880         0       False      True       True       False
# ...   ...     ...       ...         ...       ...        ...         ...
# 1333   50  30.970         3       False      True       True       False
# 1334   18  31.920         0        True     False       True       False
# 1335   18  36.850         0        True     False       True       False
# 1336   21  25.800         0        True     False       True       False
# 1337   61  29.070         0        True     False      False        True
#
# [1338 rows x 7 columns]

# %%
dependent=dataset['charges']
dependent
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent,dependent, test_size = 1, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid ={'criterion': ['squared_error', 'absolute_error'],
'max_features': [None,'sqrt','log2'],
'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_   #storing all the results of the gridsearch intp a variable 're'
print("The R_score value for best parameter {}:".format(grid.best_params_))  # printing the parameter of the best model
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re) 
table  #printing all the result thats stored in the variable 're'
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.104705      0.003959         0.015739        0.012799
# 1        0.940369      0.014881         0.026686        0.003069
# 2        0.075700      0.003919         0.005311        0.000981
# 3        0.640669      0.006915         0.025887        0.001207
# 4        0.068324      0.001863         0.006208        0.001315
# 5        0.627181      0.008265         0.027222        0.003664
# 6        0.470276      0.009754         0.004569        0.000834
# 7        4.144483      0.029357         0.016571        0.004007
# 8        0.217696      0.007091         0.005007        0.000879
# 9        2.034698      0.017958         0.024047        0.002700
# 10       0.221645      0.003977         0.005627        0.000740
# 11       2.024685      0.034643         0.024010        0.002863
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               None                  10
# 1    squared_error               None                 100
# 2    squared_error               sqrt                  10
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                 100
# 6   absolute_error               None                  10
# 7   absolute_error               None                 100
# 8   absolute_error               sqrt                  10
# 9   absolute_error               sqrt                 100
# 10  absolute_error               log2                  10
# 11  absolute_error               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.871793
# 1   {'criterion': 'squared_error', 'max_features':...           0.874791
# 2   {'criterion': 'squared_error', 'max_features':...           0.876356
# 3   {'criterion': 'squared_error', 'max_features':...           0.894663
# 4   {'criterion': 'squared_error', 'max_features':...           0.889755
# 5   {'criterion': 'squared_error', 'max_features':...           0.894643
# 6   {'criterion': 'absolute_error', 'max_features'...           0.861661
# 7   {'criterion': 'absolute_error', 'max_features'...           0.873713
# 8   {'criterion': 'absolute_error', 'max_features'...           0.889745
# 9   {'criterion': 'absolute_error', 'max_features'...           0.889502
# 10  {'criterion': 'absolute_error', 'max_features'...           0.888550
# 11  {'criterion': 'absolute_error', 'max_features'...           0.897277
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.848617           0.746995           0.801098
# 1            0.870631           0.753907           0.834864
# 2            0.838771           0.730383           0.819626
# 3            0.863622           0.773602           0.841311
# 4            0.857666           0.736478           0.835526
# 5            0.868437           0.770919           0.838650
# 6            0.867865           0.753232           0.821155
# 7            0.864633           0.754792           0.825746
# 8            0.836052           0.758685           0.820526
# 9            0.870497           0.770854           0.844801
# 10           0.825602           0.752623           0.821810
# 11           0.867308           0.771113           0.842980
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.795012         0.812703        0.043696               11
# 1            0.789324         0.824703        0.046872                5
# 2            0.778874         0.808802        0.050247               12
# 3            0.790947         0.832829        0.044957                3
# 4            0.769338         0.817753        0.056644                8
# 5            0.788043         0.832138        0.046816                4
# 6            0.774754         0.815733        0.045699                9
# 7            0.790668         0.821910        0.044731                6
# 8            0.784650         0.817932        0.044967                7
# 9            0.793484         0.833828        0.045073                2
# 10           0.778837         0.813484        0.046380               10
# 11           0.790486         0.833833        0.046994                1

# %%
grid.best_score_   #printing the r_score of the best combination of the parameter
# Out:
# 0.8338326297906603

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))                                     
children_input=float(input("Children:"))                           #all the input values for prediction
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 45
# BMI: 34
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1
